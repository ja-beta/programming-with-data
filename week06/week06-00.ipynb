# %%
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./PRSA_data_2010.1.1-2014.12.31.csv")

# %%
df
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df.plot(y=["Ir", "Is", "TEMP"])
# Out:
# <Axes: >

# %% [markdown]
# # Histograms!

# %%
df.plot(kind="hist", y="TEMP")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# each bar corresponds to the number of times the value repeats.
# Histograms with floating number (rather than integers) is different:
# it looks at ranges and divides the data into bins - equally spaced areas along the x axis,
# and then it sees, for each data point, what bin does it fit in.
# We get to pick the number of bins! (default is 10) ->

# %%
df.plot(kind="hist", y="TEMP", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# this looks like bi-modal distribution which is like two normal distriburions on top of each other

# %%
df.plot(kind="hist", y="pm2.5", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#this looks more like power law distribution: most frequent things are lowest, and as intensity rises the freuency falls

# %%
df.plot(kind="hist", y="month", bins=12)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#this is pretty much uniform distribution

# %%
df.plot(kind="hist", y="day", bins=31)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["month"].value_counts().plot(kind="bar") #better for discrete data likr months)
# Out:
# <Axes: xlabel='month'>

# %%
df["cbwd"].value_counts().plot(kind="barh") #cv is like "calm", no measurable wind
# Out:
# <Axes: ylabel='cbwd'>

# %%
df["Iws"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # scatter plots!

# %%
df.plot(kind="scatter", x="DEWP" , y="TEMP")
# Out:
# <Axes: xlabel='DEWP', ylabel='TEMP'>

# %%
# there is a pretty strong positive correlation between the two parameters.
# we can also see outliers and further investigate them if needed

# %%
df.plot(kind="scatter", x="pm2.5", y="Iws")
# Out:
# <Axes: xlabel='pm2.5', ylabel='Iws'>

# %%
# pretty much strong negative correlation. Outliers might be noise but are worth looking into

# %%
df.plot(kind="scatter", x="year", y="month")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
#the values are clearly not correlated in a meaningful way (uniform distribution) - there is the same number of months per year.

# %%
df.plot(kind="scatter", x="pm2.5", y="Iws", s="month", c="TEMP") # s is for size of the dot, c is for color
# Out:
# <Axes: xlabel='pm2.5', ylabel='Iws'>

# %%
# now we can see more information, another dimension of data

# %% [markdown]
# # sorting!

# %%
df.sort_values(by="pm2.5", ascending=False) # we sort by particulate matter from biggest to smallest
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 18049  18050  2012      1   23     1  994.0   -24 -12.0  1032.0   NW    4.92
# 1057    1058  2010      2   14     1  980.0   -14  -7.0  1029.0   cv    0.89
# 18050  18051  2012      1   23     2  972.0   -24 -12.0  1032.0   NW    8.05
# 26588  26589  2013      1   12    20  886.0    -8  -7.0  1023.0   cv    1.34
# 26590  26591  2013      1   12    22  858.0   -10  -9.0  1024.0   cv    0.89
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43548  43549  2014     12   20    12    NaN   -18   0.0  1030.0   NW  244.97
# 43549  43550  2014     12   20    13    NaN   -19   1.0  1029.0   NW  249.89
# 43550  43551  2014     12   20    14    NaN   -20   1.0  1029.0   NW  257.04
# 43551  43552  2014     12   20    15    NaN   -20   2.0  1028.0   NW  262.85
# 43552  43553  2014     12   20    16    NaN   -21   1.0  1028.0   NW  270.00
#
#        Is  Ir
# 18049   0   0
# ...

# %%
df.sort_values(by="Is", ascending=False)[:10] #top 10 snowiest days
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 69        70  2010      1    3    21   72.0   -11 -10.0  1023.0   NW    7.15
# 68        69  2010      1    3    20   71.0   -10  -9.0  1022.0   NW    4.02
# 67        68  2010      1    3    19   53.0   -11  -9.0  1022.0   cv    1.78
# 66        67  2010      1    3    18   61.0   -11  -9.0  1021.0   cv    0.89
# 65        66  2010      1    3    17   70.0   -11  -9.0  1020.0   SE  127.84
# 35980  35981  2014      2    8     4  115.0    -7  -4.0  1024.0   cv    0.89
# 64        65  2010      1    3    16   86.0   -11  -9.0  1020.0   SE  124.71
# 35979  35980  2014      2    8     3   88.0    -6  -4.0  1025.0   SE   72.00
# 63        64  2010      1    3    15   95.0   -11  -9.0  1020.0   SE  121.58
# 35978  35979  2014      2    8     2   94.0    -6  -4.0  1025.0   SE   71.11
#
#        Is  Ir
# 69     27   0
# 68     26   0
# 67     25   0
# 66     24   0
# 65     23   0
# 35980  23   0
# ...

# %%
df.sort_values(by="Is", ascending=False).head(1) #the same, default is first 5 rows.
# Out:
#     No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd   Iws  Is  Ir
# 69  70  2010      1    3    21   72.0   -11 -10.0  1023.0   NW  7.15  27   0

# %%
sorted_df = df.sort_values(by="pm2.5", ascending=False) #saving the sorted dataframe as a new dataframe. The original remains unchanged.

# %%
sorted_df.head(25).plot(kind="bar", y="pm2.5") #top 25 most polluted days
# Out:
# <Axes: >

# %%
df.sort_values(by=["TEMP", "hour"], ascending=False) 
#sorting the primary fields by a secondary one - how to sort between values that are identical. 
# used to make sure that identical items also have meaningful ordering.
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 38631  38632  2014      5   29    15   19.0     4  42.0   996.0   NW    5.81
# 4457    4458  2010      7    5    17   12.0     5  41.0   997.0   NW   33.09
# 4456    4457  2010      7    5    16   13.0     5  41.0   997.0   NW   28.17
# 4455    4456  2010      7    5    15   10.0     5  41.0   998.0   NW   20.12
# 4479    4480  2010      7    6    15    7.0     6  41.0   999.0   SE    7.15
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 267      268  2010      1   12     3   26.0   -24 -18.0  1030.0   NE    1.79
# 146      147  2010      1    7     2   43.0   -22 -18.0  1036.0   cv    1.34
# 97        98  2010      1    5     1   34.0   -26 -18.0  1035.0   NW  205.60
# 100      101  2010      1    5     4   28.0   -27 -19.0  1035.0   NW  218.57
# 98        99  2010      1    5     2   27.0   -26 -19.0  1035.0   NW  208.73
#
#        Is  Ir
# 38631   0   0
# ...

# %% [markdown]
# # Grouping!
# We would usually want to use groupby by values that are discrete and not continuous (like hours, months...)

# %%
df
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df[df["month"] == 1] #a dataframe that only has data where month is 1
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...    ...
# 35803  35804  2014      1   31    19  140.0    -7   1.0  1019.0   cv   2.67
# 35804  35805  2014      1   31    20  148.0    -5   2.0  1019.0   cv   3.56
# 35805  35806  2014      1   31    21  155.0    -5   2.0  1019.0   cv   4.45
# 35806  35807  2014      1   31    22  167.0    -5   2.0  1019.0   cv   4.90
# 35807  35808  2014      1   31    23  180.0    -4   2.0  1019.0   cv   5.79
#
#        Is  Ir
# 0       0   0
# 1       0   0
# ...

# %%
df[df["month"] == 1]["pm2.5"].mean() #average of pm across january
# Out:
# np.float64(115.05906078939786)

# %%
df[df["month"] == 2]["pm2.5"].mean() #same for february
# Out:
# np.float64(125.73613993477616)

# %%
df.groupby("month")

# %%
#evaluates to this dataframe groupby object... it lets us take the values and perform aggregation on it (mean, max, std...)

# %%
df.groupby("month").mean(numeric_only=True) #get average for every column by month
# Out:
#             No    year        day  hour       pm2.5       DEWP       TEMP  \
# month
# 1      17902.1  2012.0  16.000000  11.5  115.059061 -16.035484  -4.553226
# 2      18612.5  2012.0  14.602837  11.5  125.736140 -12.941489  -1.569149
# 3      19322.9  2012.0  16.000000  11.5   97.757593  -8.890591   6.080914
# 4      20054.9  2012.0  15.500000  11.5   83.709251  -1.495278  13.995833
# 5      20786.9  2012.0  16.000000  11.5   80.113051   7.227688  21.302151
# 6      21518.9  2012.0  15.500000  11.5   96.513656  16.112778  24.586389
# 7      22250.9  2012.0  16.000000  11.5   94.332328  20.574194  27.197312
# 8      22994.9  2012.0  16.000000  11.5   79.996704  19.271237  25.823118
# 9      23726.9  2012.0  15.500000  11.5   85.209421  12.886389  20.032778
# 10     24458.9  2012.0  16.000000  11.5  120.401509   5.049194  12.997849
# 11     25190.9  2012.0  15.500000  11.5  105.762639  -6.058889   4.964444
# 12     25922.9  2012.0  16.000000  11.5   98.200226 -14.768548  -2.297581
# ...

# %%
df.groupby("month").mean(numeric_only=True)["Iws"] #just for a particular column of the aggregation
# Out:
# month
# 1     36.248516
# 2     18.074938
# 3     26.959089
# 4     33.642358
# 5     27.093737
# 6     11.326483
# 7     13.733753
# 8     12.104952
# 9     11.080028
# 10    13.620694
# 11    38.114533
# 12    44.100500
# Name: Iws, dtype: float64

# %%
df.groupby("hour").max(numeric_only=True) #the max for each field by day
# Out:
#          No  year  month  day  pm2.5  DEWP  TEMP    PRES     Iws  Is  Ir
# hour
# 0     43801  2014     12   31  744.0    27  32.0  1046.0  570.41  19  28
# 1     43802  2014     12   31  994.0    27  31.0  1046.0  573.54  20  29
# 2     43803  2014     12   31  972.0    26  30.0  1046.0  577.56  21  30
# 3     43804  2014     12   31  684.0    26  30.0  1046.0  581.58  22  31
# 4     43805  2014     12   31  700.0    26  30.0  1046.0  585.60  23  32
# 5     43806  2014     12   31  673.0    26  30.0  1045.0  403.19  10  33
# 6     43807  2014     12   31  618.0    27  30.0  1045.0  409.05  10  34
# 7     43808  2014     12   31  532.0    27  31.0  1045.0  416.20  11  35
# 8     43809  2014     12   31  519.0    28  32.0  1046.0  424.25  12  36
# 9     43810  2014     12   31  526.0    28  34.0  1046.0  434.08  13  24
# 10    43811  2014     12   31  784.0    27  36.0  1046.0  447.04  15  25
# 11    43812  2014     12   31  761.0    27  38.0  1046.0  458.22  16  26
# ...

# %%
df.groupby("hour").max(numeric_only=True)["pm2.5"] #just for polution - max polution by hour of day
# Out:
# hour
# 0     744.0
# 1     994.0
# 2     972.0
# 3     684.0
# 4     700.0
# 5     673.0
# 6     618.0
# 7     532.0
# 8     519.0
# 9     526.0
# 10    784.0
# 11    761.0
# 12    551.0
# 13    562.0
# 14    542.0
# 15    802.0
# 16    845.0
# 17    810.0
# 18    776.0
# 19    824.0
# 20    886.0
# 21    852.0
# 22    858.0
# 23    805.0
# Name: pm2.5, dtype: float64

# %%
df.groupby("hour").max(numeric_only=True)["pm2.5"].plot()
# Out:
# <Axes: xlabel='hour'>

# %%
mean_by_month_df = df.groupby("month").mean(numeric_only=True)

# %%
mean_by_month_df
# Out:
#             No    year        day  hour       pm2.5       DEWP       TEMP  \
# month
# 1      17902.1  2012.0  16.000000  11.5  115.059061 -16.035484  -4.553226
# 2      18612.5  2012.0  14.602837  11.5  125.736140 -12.941489  -1.569149
# 3      19322.9  2012.0  16.000000  11.5   97.757593  -8.890591   6.080914
# 4      20054.9  2012.0  15.500000  11.5   83.709251  -1.495278  13.995833
# 5      20786.9  2012.0  16.000000  11.5   80.113051   7.227688  21.302151
# 6      21518.9  2012.0  15.500000  11.5   96.513656  16.112778  24.586389
# 7      22250.9  2012.0  16.000000  11.5   94.332328  20.574194  27.197312
# 8      22994.9  2012.0  16.000000  11.5   79.996704  19.271237  25.823118
# 9      23726.9  2012.0  15.500000  11.5   85.209421  12.886389  20.032778
# 10     24458.9  2012.0  16.000000  11.5  120.401509   5.049194  12.997849
# 11     25190.9  2012.0  15.500000  11.5  105.762639  -6.058889   4.964444
# 12     25922.9  2012.0  16.000000  11.5   98.200226 -14.768548  -2.297581
# ...

# %%
mean_by_month_df[mean_by_month_df["Is"] > 0] #the months where the average snowfall was greater than 0
# Out:
#             No    year        day  hour       pm2.5       DEWP      TEMP  \
# month
# 1      17902.1  2012.0  16.000000  11.5  115.059061 -16.035484 -4.553226
# 2      18612.5  2012.0  14.602837  11.5  125.736140 -12.941489 -1.569149
# 3      19322.9  2012.0  16.000000  11.5   97.757593  -8.890591  6.080914
# 11     25190.9  2012.0  15.500000  11.5  105.762639  -6.058889  4.964444
# 12     25922.9  2012.0  16.000000  11.5   98.200226 -14.768548 -2.297581
#
#               PRES        Iws        Is        Ir
# month
# 1      1028.830376  36.248516  0.204301  0.004032
# 2      1025.862145  18.074938  0.248227  0.002069
# 3      1020.742204  26.959089  0.088978  0.078226
# 11     1022.681250  38.114533  0.001111  0.196667
# 12     1026.692742  44.100500  0.101075  0.001882

# %%
mean_by_month_df.sort_values(by="pm2.5", ascending=False) #order the months by average pollution value
# Out:
#             No    year        day  hour       pm2.5       DEWP       TEMP  \
# month
# 2      18612.5  2012.0  14.602837  11.5  125.736140 -12.941489  -1.569149
# 10     24458.9  2012.0  16.000000  11.5  120.401509   5.049194  12.997849
# 1      17902.1  2012.0  16.000000  11.5  115.059061 -16.035484  -4.553226
# 11     25190.9  2012.0  15.500000  11.5  105.762639  -6.058889   4.964444
# 12     25922.9  2012.0  16.000000  11.5   98.200226 -14.768548  -2.297581
# 3      19322.9  2012.0  16.000000  11.5   97.757593  -8.890591   6.080914
# 6      21518.9  2012.0  15.500000  11.5   96.513656  16.112778  24.586389
# 7      22250.9  2012.0  16.000000  11.5   94.332328  20.574194  27.197312
# 9      23726.9  2012.0  15.500000  11.5   85.209421  12.886389  20.032778
# 4      20054.9  2012.0  15.500000  11.5   83.709251  -1.495278  13.995833
# 5      20786.9  2012.0  16.000000  11.5   80.113051   7.227688  21.302151
# 8      22994.9  2012.0  16.000000  11.5   79.996704  19.271237  25.823118
# ...

# %%
mean_by_month_df.plot(kind="bar", y=["pm2.5", "Iws", "TEMP"])
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## working with columns
# adding or removing columns from a dataframe and more!

# %%
simple_df = df.drop(columns=["Ir", "Is", "Iws","cbwd", "year", "month", "day", "hour", "No"]) 
#will return a new dataframe that does not have the specified columns
#could add a parameter inplace=True if we want to apply it to the original df like:
# simple_df = df.drop(columns=["Ir", "Is", "Iws","cbwd", "year", "month", "day", "hour", "No"], inplace=True)

# %%
simple_df
# Out:
#        pm2.5  DEWP  TEMP    PRES
# 0        NaN   -21 -11.0  1021.0
# 1        NaN   -21 -12.0  1020.0
# 2        NaN   -21 -11.0  1019.0
# 3        NaN   -21 -14.0  1019.0
# 4        NaN   -20 -12.0  1018.0
# ...      ...   ...   ...     ...
# 43819    8.0   -23  -2.0  1034.0
# 43820   10.0   -22  -3.0  1034.0
# 43821   10.0   -22  -3.0  1034.0
# 43822    8.0   -22  -4.0  1034.0
# 43823   12.0   -21  -3.0  1034.0
#
# [43824 rows x 4 columns]

# %%
simple_df.plot()
# Out:
# <Axes: >

# %%
df.assign(all_ones=1) #adding a column. If it was a series instead of one number it would add it by order
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir  all_ones
# ...

# %%
american_df = df.assign(god_bless_american_temperature=df["TEMP"] * (9/5) + 32) #adding a column that converts celsius to fahrenheit

# %%
american_df
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
# ...

# %% [markdown]
# ## column data types

# %%
museum_data = """\
Number,Street,Zip,Price
200,Central Park West,10024,$28
200,Eastern Parkway,11238,$20
1071,Fifth Avenue,10128,$30
1000,Fifth Avenue,10028,$25
11,West 53rd Street,10019,$25"""

from io import StringIO
museum_df = pd.read_csv(StringIO(museum_data))

# %%
museum_df
# Out:
#    Number             Street    Zip Price
# 0     200  Central Park West  10024   $28
# 1     200    Eastern Parkway  11238   $20
# 2    1071       Fifth Avenue  10128   $30
# 3    1000       Fifth Avenue  10028   $25
# 4      11   West 53rd Street  10019   $25

# %%
museum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Number  5 non-null      int64
#  1   Street  5 non-null      object
#  2   Zip     5 non-null      int64
#  3   Price   5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
# two bad guesses - zipcodes are not integers (0 is important to have), and price should be number.
# so we want to be able to fix that
# available types are: int, bool, float, str

# %%
museum_df["Zip"].astype(str)
# Out:
# 0    10024
# 1    11238
# 2    10128
# 3    10028
# 4    10019
# Name: Zip, dtype: object

# %%
museum_df.assign(zip_str=museum_df["Zip"].astype(str))
# Out:
#    Number             Street    Zip Price zip_str
# 0     200  Central Park West  10024   $28   10024
# 1     200    Eastern Parkway  11238   $20   11238
# 2    1071       Fifth Avenue  10128   $30   10128
# 3    1000       Fifth Avenue  10028   $25   10028
# 4      11   West 53rd Street  10019   $25   10019

# %%
# For the price we can't just change the type, we have to remove the "$"

# %%
fixed_museum_df = museum_df.assign(price_int=museum_df["Price"].str[1:].astype(int)) 
#give me everything after the first character, convert to int, add a column and save as a new dataframe

# %%
fixed_museum_df
# Out:
#    Number             Street    Zip Price  price_int
# 0     200  Central Park West  10024   $28         28
# 1     200    Eastern Parkway  11238   $20         20
# 2    1071       Fifth Avenue  10128   $30         30
# 3    1000       Fifth Avenue  10028   $25         25
# 4      11   West 53rd Street  10019   $25         25

# %%
fixed_museum_df["price_int"].mean()
# Out:
# np.float64(25.6)
