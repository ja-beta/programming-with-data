# %% [markdown]
# # Freedom of Information complaints
#
# The Israeli Government Freedom of Information Unit has the authority to investigate complaints about government ministries and their subsidiary units regarding:
#
# * failure to publish annual reports and treports about the implementation of the Freedom of Information Act
# * failure to publish information initiated by virtue of the law - administrative guidelines and environmental information – without a lawful explanation
# * failure to respond to a request for information within the time frame or date set by law
# * rejection of a request for information without a lawful explanation
# * the manner in which fees are calculated, except fee exemptions
#
#
# The database in this notebook comprises of 689 complaints made to the Freedom of Information Unit from April 25th 2021, to November 28th 2024(it is updated daily).
#
# The original file is in Hebrew — Jupyter notebook refused to open it, so I manually translated all recurring terms in Google Spreadsheets. Wherever relevant, additional translation will be provided in comments.

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10, 4)

# %%
df = pd.read_csv("./complaints - b460e022-0f7c-48c6-ba64-ce16e1340056 (1).csv")

# %%
df
# Out:
#     complaint_number request_date complaint_date complaint_channel  \
# 0             368/24   22/11/2023     28/10/2024       online form
# 1             217/21   17/11/2020     01/05/2021       online form
# 2             218/21   29/10/2020     01/05/2021       online form
# 3             220/21   29/10/2020     01/05/2021       online form
# 4             221/21   29/10/2020     01/05/2021       online form
# ..               ...          ...            ...               ...
# 683           103/24   08/11/2023     02/04/2024       online form
# 684           312/24   25/08/2024     04/09/2024       online form
# 685           211/24   11/01/2024     19/06/2024       online form
# 686           459/22   16/08/2022     29/11/2022       online form
# 687           306/22   14/06/2022     21/07/2022       online form
#
#              complainer_kind complainer_name     complaint_topic  \
# 0                    citizen             NaN  failure to respond
# 1                    citizen             NaN  failure to respond
# 2                    citizen             NaN  failure to respond
# 3                    citizen             NaN  failure to respond
# 4                    citizen             NaN  failure to respond
# ..                       ...             ...                 ...
# 683                  citizen             NaN  failure to respond
# 684                  citizen             NaN   lack of reasoning
# 685  non-profit organization           מוסרי  failure to respond
# 686                  citizen             NaN  failure to respond
# 687                  citizen             NaN  failure to respond
#
#                                     complaint_against  \
# 0                                 משרד הבינוי והשיכון
# 1                                     בית חולים רמבם"
# 2                         המרכז לבריאות הנפש שער מנשה
# 3    המרכז לבריאות הנפש באר-יעקב נס-ציונה מבן (שב"ס)"
# 4                            מרכז בריאות הנפש באר שבע
# ..                                                ...
# 683                                      משרד המשפטים
# 684                                 בית חולים איכילוב
# 685                               המשרד לשוויון חברתי
# 686                                      משרד הבריאות
# 687                      משרד התחבורה והבטיחות בדרכים
#
#                                 original_request_topic  \
# 0                   בירור פרטני לעניין קביעת שכר הדירה
# 1                        נתונים על מחלקות פסיכיאטריות
# 2                        נתונים על מחלקות פסיכיאטריות
# 3                        נתונים על מחלקות פסיכיאטריות
# 4                        נתונים על מחלקות פסיכיאטריות
# ..                                                 ...
# 683  failure to respond !במועד! סמוכין 395054 תאריך...
# 684                         תחלופת עובדים בלשכות הנהלה
# 685                            הסכמי התקשוריות ומכרזים
# 686                                 בידוד נגיף הקורונה
# 687                            תחומי otherיות כפר יונה
#
#                        status             decision termination_date  \
# 0    termination of treatment          unjustified       04/11/2024
# 1    termination of treatment          unjustified       23/05/2021
# 2    termination of treatment            justified       17/11/2021
# 3    termination of treatment            justified       17/11/2021
# 4    termination of treatment            justified       17/11/2021
# ..                        ...                  ...              ...
# 683  termination of treatment          unjustified       03/04/2024
# 684  termination of treatment          unjustified       09/09/2024
# 685  termination of treatment            justified       27/06/2024
# 686  termination of treatment            justified       02/03/2023
# 687  termination of treatment  justified partially       25/07/2022
#
#      days_to_treat
# 0                7
# 1               22
# 2              200
# 3              200
# 4              200
# ..             ...
# 683              1
# 684              5
# 685              8
# 686             93
# 687              5
#
# [688 rows x 13 columns]

# %% [markdown]
# # cleaning the data

# %%
df = df.drop(columns=["complaint_number"])
df
# Out:
#     request_date complaint_date complaint_channel          complainer_kind  \
# 0     22/11/2023     28/10/2024       online form                  citizen
# 1     17/11/2020     01/05/2021       online form                  citizen
# 2     29/10/2020     01/05/2021       online form                  citizen
# 3     29/10/2020     01/05/2021       online form                  citizen
# 4     29/10/2020     01/05/2021       online form                  citizen
# ..           ...            ...               ...                      ...
# 683   08/11/2023     02/04/2024       online form                  citizen
# 684   25/08/2024     04/09/2024       online form                  citizen
# 685   11/01/2024     19/06/2024       online form  non-profit organization
# 686   16/08/2022     29/11/2022       online form                  citizen
# 687   14/06/2022     21/07/2022       online form                  citizen
#
#     complainer_name     complaint_topic  \
# 0               NaN  failure to respond
# 1               NaN  failure to respond
# 2               NaN  failure to respond
# 3               NaN  failure to respond
# 4               NaN  failure to respond
# ..              ...                 ...
# 683             NaN  failure to respond
# 684             NaN   lack of reasoning
# 685           מוסרי  failure to respond
# 686             NaN  failure to respond
# 687             NaN  failure to respond
#
#                                     complaint_against  \
# 0                                 משרד הבינוי והשיכון
# 1                                     בית חולים רמבם"
# 2                         המרכז לבריאות הנפש שער מנשה
# 3    המרכז לבריאות הנפש באר-יעקב נס-ציונה מבן (שב"ס)"
# 4                            מרכז בריאות הנפש באר שבע
# ..                                                ...
# 683                                      משרד המשפטים
# 684                                 בית חולים איכילוב
# 685                               המשרד לשוויון חברתי
# 686                                      משרד הבריאות
# 687                      משרד התחבורה והבטיחות בדרכים
#
#                                 original_request_topic  \
# 0                   בירור פרטני לעניין קביעת שכר הדירה
# 1                        נתונים על מחלקות פסיכיאטריות
# 2                        נתונים על מחלקות פסיכיאטריות
# 3                        נתונים על מחלקות פסיכיאטריות
# 4                        נתונים על מחלקות פסיכיאטריות
# ..                                                 ...
# 683  failure to respond !במועד! סמוכין 395054 תאריך...
# 684                         תחלופת עובדים בלשכות הנהלה
# 685                            הסכמי התקשוריות ומכרזים
# 686                                 בידוד נגיף הקורונה
# 687                            תחומי otherיות כפר יונה
#
#                        status             decision termination_date  \
# 0    termination of treatment          unjustified       04/11/2024
# 1    termination of treatment          unjustified       23/05/2021
# 2    termination of treatment            justified       17/11/2021
# 3    termination of treatment            justified       17/11/2021
# 4    termination of treatment            justified       17/11/2021
# ..                        ...                  ...              ...
# 683  termination of treatment          unjustified       03/04/2024
# 684  termination of treatment          unjustified       09/09/2024
# 685  termination of treatment            justified       27/06/2024
# 686  termination of treatment            justified       02/03/2023
# 687  termination of treatment  justified partially       25/07/2022
#
#      days_to_treat
# 0                7
# 1               22
# 2              200
# 3              200
# 4              200
# ..             ...
# 683              1
# 684              5
# 685              8
# 686             93
# 687              5
#
# [688 rows x 12 columns]

# %% [markdown]
# # preliminary analysis
# Lots of pie charts!

# %%
df.value_counts("complainer_kind")
# Out:
# complainer_kind
# citizen                    479
# non-profit organization    150
# other                       39
# company                     20
# Name: count, dtype: int64

# %%
df["complainer_kind"].value_counts().plot(kind="pie", autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### why did people complain?

# %%
df.value_counts("complaint_topic")
# Out:
# complaint_topic
# failure to respond    641
# lack of reasoning      47
# Name: count, dtype: int64

# %%
df["complaint_topic"].value_counts().plot(kind="pie", autopct='%1.000f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### who's filing complaints?

# %%
df["complainer_kind"].value_counts()
# Out:
# complainer_kind
# citizen                    479
# non-profit organization    150
# other                       39
# company                     20
# Name: count, dtype: int64

# %% [markdown]
# ### what was the unit's decision?

# %%
df["decision"].value_counts()
# Out:
# decision
# justified              460
# unjustified            198
# justified partially     15
# Name: count, dtype: int64

# %%
df["decision"].value_counts().plot(kind="pie", autopct='%1.0000f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### How did people complain?

# %%
df["complaint_channel"].value_counts().plot(kind="pie", autopct='%1.0000f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Current status

# %%
df["status"].value_counts().plot(kind="pie", autopct='%1.0000f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## How many days does it take to treat a complaint?

# %%
df["days_to_treat"].describe()
# Out:
# count    688.000000
# mean      78.603198
# std       84.508621
# min        0.000000
# 25%       20.000000
# 50%       49.000000
# 75%      106.250000
# max      693.000000
# Name: days_to_treat, dtype: float64

# %% [markdown]
# ### a dataframe of all complaints that took a year and longer to treat

# %%
long_complaints = df[df["days_to_treat"] > 364 ]
long_complaints
# Out:
#     request_date complaint_date complaint_channel complainer_kind  \
# 36    22/05/2019     17/06/2021       online form           other
# 145   04/04/2022     06/08/2022             email         citizen
# 202   20/06/2021     09/08/2022       online form           other
# 348   23/11/2022     08/01/2023       online form         citizen
# 593   24/04/2022     16/06/2022       online form         citizen
# 682   16/04/2023     24/05/2023       online form         citizen
#
#     complainer_name     complaint_topic               complaint_against  \
# 36              NaN  failure to respond  משרד הרווחה והשירותים החברתיים
# 145             NaN   lack of reasoning             משרד הבינוי והשיכון
# 202             NaN  failure to respond                    משרד המשפטים
# 348             NaN  failure to respond              המשרד להגנת הסביבה
# 593             NaN   lack of reasoning  משרד הרווחה והשירותים החברתיים
# 682             NaN   lack of reasoning                     משטרת ישראל
#
#                                 original_request_topic  \
# 36   הכרעת דין בנושא עגורנים שהועברה למשרד העבודה ל...
# 145       קבלת מסמכים לפרויקט מחיר למשתכן שבירו רמת גן
# 202                               מסמכים שונים -יועמש"
# 348                   מסדרון וצוואר בקבוק אקולוגי גדרה
# 593                      מידע אודות הוסטל נחלים ברכסים
# 682                סירוב גורף לבקשת מידע  מיום 16.4.23
#
#                        status     decision termination_date  days_to_treat
# 36   termination of treatment  unjustified       11/05/2023            693
# 145  termination of treatment    justified       24/01/2024            535
# 202  termination of treatment    justified       31/12/2023            509
# 348  termination of treatment  unjustified       22/05/2024            500
# 593  termination of treatment  unjustified       09/04/2024            663
# 682  termination of treatment  unjustified       01/08/2024            435

# %% [markdown]
# Two complaints were made against the office of social services, one against the Ministry of Construction and Housing, one for the Ministry of Justice, one for the Ministry of Environmental Protection, and one for the Israeli Police.

# %% [markdown]
# ### What about the complaints that were closed immediately?

# %%
short_complaints = df[df["days_to_treat"] < 1]
short_complaints
# Out:
#     request_date complaint_date complaint_channel complainer_kind  \
# 98    02/11/2023     07/01/2024             email         citizen
# 169   20/02/2024     20/03/2024             email         citizen
# 294   22/10/2022     22/12/2022       online form         citizen
# 399   09/11/2023     15/04/2024       online form         citizen
# 455   03/07/2023     10/07/2023       online form         citizen
# 458   07/11/2023     03/04/2024       online form         citizen
# 555   24/11/2023     13/05/2024       online form         citizen
# 564   04/02/2023     11/05/2023       online form         citizen
#
#     complainer_name     complaint_topic  complaint_against  \
# 98              NaN  failure to respond        משרד החינוך
# 169             NaN  failure to respond         משרד הפנים
# 294             NaN  failure to respond    הנהלת בתי המשפט
# 399             NaN  failure to respond       משרד המשפטים
# 455             NaN  failure to respond  רשות מקרקעי ישראל
# 458             NaN  failure to respond       משרד המשפטים
# 555             NaN  failure to respond       משרד המשפטים
# 564             NaN   lack of reasoning       משרד המשפטים
#
#                                 original_request_topic  \
# 98                                              מסמכים
# 169                                         תיקי פיקוח
# 294                            בקשת מידע צווים שיפוטים
# 399   failure to respond סמוכין 395069 תאריך 09.11.23
# 455                                    מידע על עסקאות
# 458  failure to respond !במועד! סמוכין 394794 תאריך...
# 555  failure to respond ! במועד ! סמוכין 396840 תאר...
# 564                             פרוטוקולים לשכת היועמש
#
#                        status     decision termination_date  days_to_treat
# 98   termination of treatment  unjustified       10/01/2024              0
# 169  termination of treatment  unjustified       20/03/2024              0
# 294  termination of treatment  unjustified       22/12/2022              0
# 399  termination of treatment  unjustified       15/04/2024              0
# 455  termination of treatment  unjustified       10/07/2023              0
# 458  termination of treatment  unjustified       03/04/2024              0
# 555  termination of treatment  unjustified       13/05/2024              0
# 564  termination of treatment  unjustified       11/05/2023              0

# %% [markdown]
# Five out of the eight entries are complaints against the Ministry of Justice.

# %% [markdown]
# ### Is there a correlation between the time it took to treat the complaint and the decision the unit made eventually?
#
# I was searching for types of charts that could be used for that. The problem was that days_to_treat is an int while decision is a string - but it only has 3 possible values. I've considered converting them into numbers and using scatter plot but it sounded like it would'nt make much sense, so I kept searching. I stumbled across a type of plot called 'violin plot' that seemed to make the most sense for this case, and found the [seaborn](https://seaborn.pydata.org/generated/seaborn.violinplot.html) library that seemed straightforward enough.

# %%
import seaborn as sns

# %%
sns.violinplot(
    data=df, 
    x="decision", 
    y="days_to_treat", 
    hue="decision", 
    density_norm="count",
    bw_adjust=0.15, 
    inner_kws=dict(box_width=8, whis_width=1, color=".15"), 
    palette=["#FF9F76", "#CCEEAE", "#F9FF88"]
)

#adding annotation for the counts
for category in df["decision"].value_counts().index:
    x_position = list(df["decision"].value_counts().index).index(category)
    plt.text(
        x_position, 
        df["days_to_treat"].max() * 0.5, 
        f"Count: {df["decision"].value_counts()[category]}",
        ha="center", fontsize=10, color="grey"
    )


plt.title("Days to Treat vs Decision")
plt.rcParams["figure.figsize"] = (10, 8)
plt.show()

# %% [markdown]
# In a violin plot, the inner box represents the interquartile range of the data for each category.
#
# It goes from the 25th percentile and the 75th percentile of the data.
# The horizontal line inside the box represents the median (50th percentile).
# The "whiskers" extend to show the whole range of data excluding outliers.
#
# The outer shape of the violin plot represents the density of the data (how frequently values occur) smoothed out by a kernel density estimation.
#
# **So what can we learn from this plot?**
# Most complaints close within 100 days, and for those that take longer, they are most likely justified.
# But if something takes **very** long to treat, it's likely to be unjustified. It also seems like there's a small bump of terminated complaints around a year into the process - this could indicate some kind of deadline or inner procedure that the unit has, but it's not that clear.
#
# ** I wanted the density of each violin to reflect the number of complaints, which is something the "density_norm" parameter should do, but it wouldn't work and I couldn't figure out why. I do think it's important to be aware of the actual counts, so I've instead included that in text.

# %% [markdown]
# ## Who were complaints filed against?

# %%
df["complaint_against"].value_counts()[:18]
# Out:
# complaint_against
# משרד הבריאות                      140
# משרד החינוך                        60
# צהל"                               57
# משרד המשפטים                       55
# משרד התחבורה והבטיחות בדרכים       40
# משרד החקלאות ופיתוח הכפר           25
# המשרד להגנת הסביבה                 23
# משרד הרווחה והשירותים החברתיים     21
# משטרת ישראל                        21
# משרד ראש הממשלה                    20
# משרד העבודה                        18
# משרד האוצר                         16
# הרשות הארצית לכבאות והצלה          15
# משרד הבינוי והשיכון                14
# הנהלת בתי הדין הרבניים             14
# משרד התיירות                       13
# רשות מקרקעי ישראל                  12
# רשות האוכלוסין וההגירה             11
# Name: count, dtype: int64

# %% [markdown]
# ```
# Translation:
# Ministry of Health                      140
# Ministry of Education                   60
# IDF (Israeli army)                      57
# Ministry of Justice                     55
# Ministry of Transportation              40
# Ministry of Agriculture                 25
# Ministry of Environmental Protection    23
# Ministry of Welfare and Social Services 21
# Israel Police                           21
# Prime Minister Office                   20
# Ministry of Employment                  18
# Treasury                                16
# Fire and Rescue Authority               15
# Ministry of Construction and Housing    14
# The administration of rabbinical courts 14
# Ministry of Tourism                     13
# Israel Land Authority                   12
# Population and Immigration Authority    11
# ```

# %% [markdown]
# ### Complaints filed against VS days it took to treat the complaints

# %%
df_complaint_against = df[df["complaint_against"].isin(df["complaint_against"].value_counts().index[:18])]
sns.violinplot(
    data=df_complaint_against, 
    x="complaint_against", 
    y="days_to_treat", 
    hue="complaint_against", 
    density_norm="count",
    bw_adjust=0.2, 
    inner_kws=dict(box_width=3, whis_width=1, color=".15", marker=11),
    palette="pastel"
)

plt.xticks(rotation=90) 
plt.title("Days to Treat vs Complaint against")
plt.rcParams["figure.figsize"] = (16, 10)
plt.show()

# %% [markdown]
# **What can we possibly infer from this?** </br>
# * The leaders in longest time to treat a complaint are:
# 1. Ministry of Welfare and Social Services
# 2. Ministry of Construction and Housing
# 3. Ministry of Environmental Protection
# 4. Ministry of Justice
# 5. Israeli Police
#
# * Generally speaking, most complaints were treated within 100 days of submission. The ones that stand out in that regard are: the Ministry of the Prime Minister, the Treasury, the administration of rabbinical courts, the Ministry of Agriculture, and the Ministry of Employment.

# %% [markdown]
# ### who are the leading complainers?
# There are 4 types of complainers: citizens, non-profit orgaizations, companies, and "other". Only non-profit orgaizations have a name in the database, the others are anonymous. So lets take a look at those organizations

# %%
df_non_profit = df[df["complainer_kind"] == "non-profit organization"]
df_non_profit = df_non_profit.dropna(subset=["complainer_name"])
df_non_profit["complainer_name"].value_counts()
# Out:
# complainer_name
# איחוד הישיבות בארי                                 21
# תנו לחיות לחיות                                    12
# מגן ביטחון                                         11
# מוסרי ארגון זכויות אדם יהודי                        9
# האגודה לזכויות האזרח                                8
# אלוט                                                8
# אזרחים למען אוויר נקי                               7
# החברה להגנת הטבע                                    7
# העמותה הקהילתית גבעת מרדכי                          5
# לביא                                                4
# המרכז להעצמת האזרח                                  4
# מרכז רקמן, אוניברסיטת בר אילן                       3
# מוסרי                                               3
# תחרות - התנועה לחירות בתעסוקה                       3
# מרכז טאוב לחקר המדיניות החברתית בישראל              3
# התנועה לחופש המידע (ער)"                            3
# המכון הישראלי לדמוקרטיה                             2
# קו לעובד                                            2
# נדן - סיוע משפטי לחיילים בשירות חובה                2
# עתים - יעוץ ומידע במעגל החיים היהודי (ער)"          2
# אם תרצו                                             1
# פורום משפחות עולים                                  1
# מדעת - למען בריאות מושכלת                           1
# כושרות                                              1
# התנועה לחופש המידע                                  1
# עמותת עמרם                                          1
# תורת המדינה                                         1
# ניצנים                                              1
# הפורום לישראל ירוקה                                 1
# הפורום לתזונה בת קיימא                              1
# האגודה לזכויות האזרח בישראל                         1
# פורום דו קיום בנגב לשוויון אזרחי                    1
# טרנסג'נדרים למען צדק חברתי                          1
# ארגון אלמנות ויתומי צהל                             1
# הטלוויזיה החברתית - לקידום סדר יום חברתי בישראל     1
# תורת לחימה                                          1
# עד כאן - צעירים למען ישראל                          1
# התעוררות בירושלים                                   1
# עתים                                                1
# ק.מ.ח. קידום מקצועי חרדי ער                         1
# מען - ארגון עובדים, סניף ירושלים                    1
# יוצאים לשינוי                                       1
# עיתים                                               1
# נושמים נקי                                          1
# עתים - יעוץ ומידע במעגל החיים היהודי                1
# המשפט בשירות הזיקנה                                 1
# גישה                                                1
# שקוף                                                1
# מניפה מנוף לחיים                                    1
# פרטיות ישראל                                        1
# אנימלס                                              1
# Name: count, dtype: int64

# %% [markdown]
# This is interesting. There are many different kinds of non-profit organizations on that list, most of which only complained once.
# The top 11 (min 4 complaints including) are:
# 1. Be'eri Union of Yeshiva — an organization whose primary goal is to help people of the ultra-orthodox jewish community and provide representation and guidance before various authorities.
# 2. Let the Animal Live — an animals rights organization.
# 3. Magen Bitachon — providing assistance for employees and retirees of the Israeli Defense Forces.
# 4. Btsalmo - A "jewish human rights organization"
# 5. The Association for Civil Rights in Israel
# 6. The Israeli Society for Autistic Children
# 7. Citizens for Clear Air
# 8. Society for the Protection of Nature in Israel
# 9. Givat Mordechai Community Association - promoting actions and providing assistance for the residents of Jerusalem in general, and the residents of the Givat Mordechai neighborhood in particular.
# 10. Lavi - the municipal association for the development of education in Jerusalem
# 11. The Center for Citizen Empowerment - works to promote the performance capabilities of the Israeli government

# %%
top_complainers = df_non_profit["complainer_name"].value_counts()[:5]
top_complainers
# Out:
# complainer_name
# איחוד הישיבות בארי              21
# תנו לחיות לחיות                 12
# מגן ביטחון                      11
# מוסרי ארגון זכויות אדם יהודי     9
# האגודה לזכויות האזרח             8
# Name: count, dtype: int64

# %%
# let's try a dictionary
complaint_counts = {}

# %%
for complainer in top_complainers.index:
    complaints = df_non_profit[df_non_profit["complainer_name"] == complainer]
    
    # let's group by "complaint_against" and count the number of complaints filed
    complaint_counts = complaints.groupby("complaint_against").size().reset_index(name="complaint_count")
    
    # And then store the result in our dictionary
    complaints_data[complainer] = complaint_counts

    #then plot it
    plt.figure(figsize=(6, 3))
    plt.bar(complaint_counts["complaint_against"], complaint_counts["complaint_count"], color="thistle")
    plt.xlabel("Complaint Against")
    plt.ylabel("Number of Complaints")
    plt.title(f"Complaints Filed by {complainer}")
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# **What can we learn from this?** <br>
# * For the top organiztion, The Be'eri Union of Yeshiva, most complaints were filed against the IDF — this makes sense, because really one of the most major point of friction for ultra-orthodox jews with authority is around their avoidance of military service.
# * For the animals rights org, most complaints were filed against the Ministry of Agriculture and the Ministry of Health. This too makes sense. The ministry of Agriculture is, among other things, in charge of regulating what substances are approved for use in farm land and the like.
# * Complaints made by the organization who's assiting employees of the IDF has filed complaints against the IDF and the Treasury
# * Complaints filed by the "jewish human rights organization" were against the National Fire and Rescue Authority, the IDF, the Ministry of Justice, and the Ministry of Health. I don't know what to make of this as the complaint count seem too low to drive to any conclusions, and looking at their website, it seems like this organization tends to nitpick on certain people.
# * The Association for Civil Rights in Israel had mostly filed complaints against the Prison Authority.

# %% [markdown]
# ### Failure to respond
# I'm wondering if a "failure to respond" complaint topic results in a "justified" decision for the most part or not?

# %%
failure_to_respond = df[df["complaint_topic"] == "failure to respond"]
decision_counts = failure_to_respond["decision"].value_counts()
decision_counts
# Out:
# decision
# justified              445
# unjustified            167
# justified partially     15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 4))
plt.bar(decision_counts.index, decision_counts.values, color=["mediumspringgreen", "tomato", "powderblue"])
plt.title("decisions for complaints about failure to respond")
plt.xlabel("decision")
plt.ylabel("number of complaints")
plt.show()

# %% [markdown]
# ### What about "lack of reasoning"?

# %%
lack_of_reasoning = df[df["complaint_topic"] == "lack of reasoning"]
decision_counts_1 = lack_of_reasoning["decision"].value_counts()

plt.figure(figsize=(8, 4))
plt.bar(decision_counts_1.index, decision_counts_1.values, color=["tomato", "mediumspringgreen", "powderblue"])
plt.title("decisions for complaints about lack of reasoning")
plt.xlabel("decision")
plt.ylabel("number of complaints")
plt.show()

# %% [markdown]
# So it seems safe to say that when complaints are about not getting a reponse, the Freedom of Information Unit usually determines that the complaint is justified.
# However, when the complaint is about a not-good-enough reponse, the unit is **twice** as likely to decide that the complaint is unjustified rather than justified.

# %% [markdown]
# ### original request topic

# %%
df["original_request_topic"].unique()
# Out:
# array(['בירור פרטני לעניין קביעת שכר הדירה',
#        'נתונים על מחלקות פסיכיאטריות ', 'יומן שר המשפטים',
#        'התכנית להעברת חיסונים למדינות זרות',
#        'חומרי רקע מדיוני קבינט הקורונה ומדיניות הפרסום שלו',
#        'מרכזים אקוטיים וטיפול בערכות אונס',
#        'קבלת מידע בנושא הקרן לעסקים בערבות המדינה', 'מידע ב 3 בקשות',
#        'דוח ria', 'דוח מוניטור בנושא יישום דו"ח מבקר שנתי )2010 )61ב"',
#        'failure to respond - מעבר אלנבי פלסטינים',
#        'פרסום מניעויות דיינים', 'חולי ונפטרי נגיף הקורונה',
#        'מספר נפגעים מתקיפת כלבים', 'הנחיות בגיור',
#        'בקשת מידע לקבלת נתונים שנאספו עליי במיונים לצהל."',
#        'פרמיות סטודנטים',
#        'נתונים על מספר הפטורים שהצבא הנפיק מסיבות רפואיות-נפשיות ומספר ההתאבדויות של חיילים בתקופה של חמש שנים.',
#        'החלטה להיטל קנס על חברת הדואר',
#        'מידע על החברות שזכו במכרז להבאת תיירים מחוסנים',
#        'גיור (שתי בקשות שונות)', 'שיעורי מחזור של בקבוקים גדולים',
#        'מערך הגיור', 'חאן לבונה', 'אכיפה בתחום פסולת הבניה',
#        'failure to respond סמוכין 273664 ', 'רשיון יבואן 7315',
#        'שימועים ובדיקות לגבי מנהל',
#        'הכרעת דין בנושא עגורנים שהועברה למשרד העבודה לטיפול',
#        'נתוני תמותה בישראל', 'פרוטוקול טיפול תרופתי בחולי קורונה',
#        'דישון KCL אורגני לשנה בקרקעות ישראל',
#        'אי המצאת אסמכתאות ללא סיבה justifiedת בחוק',
#        'בקשת מידע על מפעל כנפית', ' חשיפת יומנו של נציב הכבאות',
#        'failure to respond לפי הוראות החוק', 'בית החולים הצרפתי, נצרת',
#        'אישורי מנכל משרד האוצר לוועד מקומי שערי תקווה"',
#        'אישורי מנכל משרד הפנים והממונה ביו"ש"',
#        'מספר המונשמים בכל בתי החולים בשנים הotherונות',
#        'failure to respond סמוכין 279542 11.07.21 ',
#        'יומני פגישות התייעצות לדוח RIA בקשה 260862', 'מניעויות דיינים',
#        'קבלת העתק צווי איסור פרסום',
#        'פגישות נציגי משרד התחבורה לדוח הria בקשה 264938',
#        'רישום דגם עגורן בפנקס עגורנים בקשה 260898',
#        'יומני פגישות עובדי מינהל הבטיחות לדוח הria',
#        'רישום משטרתי ליוצאי אתיופיה',
#        'מי הוא גורם מקצוע למתן תשובה במנהל הבטיחות',
#        "פניה מס' 643068 ופניה מספר 644187",
#        'תקצוב משרד התחבורה פרויקטים תחבורתיים וסובסידיות ב',
#        ' 9 בקשות שונות שלא נענו מאז 2020',
#        'מידע על הוועדה המייעצת להעברת מעונות היום', 'אדמות יהודים ביוש"',
#        'נתוני הכרה של גופים לפי סעיף 46 א',
#        'קבלת מידע בעניין כתבי אישו כנגד מי שרכב על גבי אופניים רגילות (לא חשמליים) במצב של שכרות',
#        'מתן מידע אודות חברת מעטים', 'רשימת תיקים שטרם נסגרו',
#        'בקשת מידע על תשלומי הורים בחטיבת ביניים בר לב בכפר',
#        'תנאי ביקור הנהוגים בהר הבית',
#        'שאלות לגבי בידוד הווירוס והווריאנטים ',
#        'מספר כתבי אישום שהגישה פרקליטות המדינה בשנים 2021-2015 בגין הצתה לפי סעיף 448 (א) לחוק העונשין.',
#        'מספר מקרי שריפה שנחקרו בשנים 2015-2021 בחשד להצתה',
#        'פניות למוקד הכבאות שנעשו בעכו ברמלה ובלוד בתאריכים9/5/21 ועד 17/5/21 .',
#        'התקציב שהקצתה הרשות לנושא של שיט וסירות בשנים 2007 עד 2021',
#        'תיק אישי המלא במשרד החינוך – כלל המסמכים, מכל תקופה, המצויים במשרד החינוך',
#        'הוצאות משפט""', '11 שאלות בנושא הקורונה',
#        'מינויים כמנהל עבודה באתרים',
#        'בקשה לקבלת המקור החוקי מכוחו מנקים מס הכנסה מעובדים תושבי הרשות הפלסטינית',
#        'מידע על אתר פסולת פיראטי',
#        'עסקת הפקעת מקרקעין - מתחם פיכמן חולון',
#        'אופן החלת חוק חינוך חובה וחינם',
#        'אירועי שומר החומות - פירוט המידע בדבר פיצויים ששולמו או שהוחלט כי ישולמו בגין נזקי רכוש',
#        'פרוטוקול ישיבה מ02/2022',
#        'פגישות נציגי משרד האוצר עם נציגי משרד הביטחון בנושא הפנסיה הצוברת של משרתי הקבע',
#        'בקשה לקבלת תקנה', 'הוראת שעה- מיצוי כושר השתכרות',
#        'הרחקות של תלמידים עם אוטיזם ממסגרות החינוך',
#        'קבלת מידע אודות עסק חוות השלושה', 'יפוכ יועמ"ש"',
#        'השמדות קנאביס רפואי', 'רישיונות קונסטרוקטיביים + יבוא ויצוא',
#        'נתוני משאף קנאביס רפואי', 'הגדרת מיצוי כושר השתכרות',
#        'השלכות מקווי מתח עיליים', 'מידע על התנהלות הוועדה',
#        'קבלת חווד בתת"ל 108"', 'מינוי דר אורית ניר"', 'קבלת מסמכים',
#        'מסמכים', 'הפעלת תחבורה ציבורית בשעת חירום',
#        'תוכנית שנתית של פקידי יערות',
#        'מינוי נשים לתפקידים בכירים במועצות דתיות', 'היקף סל שירותים',
#        'נתונים בנושא המלחמה', 'תמריצים לעובדי ההוראה ים המלח',
#        'פרוטוקול ועדת התקשרויות', 'פרוטוקולים ועדה למניעת הטעיית הציבור',
#        'גב נועם דן', 'מידע אודות מרכיבי שכר',
#        'רשימת כל התלונות שהגיש המתלונן למשטרה נגד גרושתו.',
#        'failure to respond על בקשת חופש מידע',
#        'שיווק תמרוקים וניסויים בבעלי חיים', 'דרגת שכר בשירות המדינה',
#        'החלטת ועדת השרים לביטחון לאומי ב/44 מיום 20.6.10',
#        'יישום תקנה 3(ב) לתקנות הבטיחות בעבודה', 'הליכי בירור יהדות',
#        'דחיית בקשה לקבלת מידע', 'הוצאות קמפיין מגן 2',
#        "נתונים בנוגע לחיילים אוכ' ייחודיות ונתוני נשר",
#        'פרטי תתומי  הורים', 'מידע לגבי מערכת מלשינון',
#        'מידע על הכשרת מורים למקצוע',
#        'הוצאות אבטחה מלון דן כרמל, לביקור נתניהו',
#        'מידע הקיים במשרד החינוך אודות אירוע אלימות שהתרחש כלפי המתלוננת בבית ספר אלונים בקרית אתא',
#        'הוראות הפרקליטות בדבר המשך חקירה', 'מאגרי מידע במשרד הבריאות',
#        'נתונים בדבר תשלום ניכויים לארגוני עובדים',
#        'אירועי הזרמת חירום של שפכים לים', 'דיור ציבורי מכר דירות',
#        'פריסת הפרסום בין כלי התקשורת', 'קרן תובענות יצוגיות',
#        'התכתובת של משרד התחבורה מול מר דינר וחברת אמבולנס סמי, בנוגע לקבלת אישור להסבת הרכב, לרכב רגיל שאינו אמבולנס',
#        'שאלות בנושא רשימון ייצוא מרוכז',
#        'נוהל הטיפול" של רישום ילד שנולד בחוץ לארץ לcitizenים ישראליים"',
#        "מידע לגבי טיפול צה''ל בחיילים שהורשעו בעבירות סמים",
#        'רשימת דוחות במסגרת יישום אזור אוויר נקי בחיפה"',
#        'עמידה בנהלי חוזרי מנכל - לימודי יסוד"', 'ישבת  דיינים בבתי דין',
#        'מידע לעניין נזקי גוף משטרת ישראל',
#        'דוח הוועדה בנושא גזענות, אפליה והדרה במערכת הבריאות',
#        'תלונות שהוגשו על ידי עיריית נס ציונה על אי שליחת ילדים למסגרת חינוכית',
#        'רישיון תמרוק ל- listerine', 'מפקחי עבודה פעילים ותאריכי הסמכה',
#        'אי קבלת מענה לפנייה 645414',
#        'קבלת מסמכים לפרויקט מחיר למשתכן שבירו רמת גן',
#        'נתונים על פעילות מערך הגיור', 'פרוטוקולים - תחנה מרכזית תל אביב',
#        "נתוני זיהום אוויר חברת קארדאטא בקשת מידע מס' 336640",
#        'תמיכה בגרעיני משימה', 'בקשת מידע על ערך הנקודה במספר תקנות',
#        'מפת חלוקת קרקעות הודיה', 'אסמכתאות לקיום הכרזה כשטח אש',
#        'שריפות פסולת', 'חוזרי המפקח על הביטוח', 'מטרדי ריח',
#        'תנאי מכרז קול הבריאות""', 'הנחיות המשרד', 'פנימיית אורנים',
#        'אסיר נזקק ועיקולים', 'רכישות בקנטינה', 'פירוט טיפול בפניות',
#        'תקציבי פרסום', 'שיתוק רפה חד', 'מסקנות ועדה',
#        "נתונים גולמיים של הגרלות הסטאז'", 'פעולות אכיפה של מינהל הבטיחות',
#        'החלת אופק חדש על החינוך המוכשר"', 'מפעילי עגורן צריח - מנופאים',
#        'תיקי פיקוח', 'גיוס מלשביות וועדות ערר"',
#        'דרוג עובדים רשות השידור', 'עיון בתיק חקירה 16020',
#        'חווד משרד המשפטים"', 'ביקורת פנימית משרד התיירות',
#        'דבש שרשת רמי לוי ייבאה לישראל',
#        'מלשבים שקיבלו מעמד של \'חוזרים בתשובה\'"', '4 תיקי חוב',
#        'ייעוץ לרהמ מטעם משרדו"', 'פליטה של מפעל הסמוך למקום מגורים',
#        'קבלת הקלטות שיחה', 'תקצוב ארגוני המורים',
#        'תמיכות, עבירות ומשמעת, ועוד', 'אכיפת איסור העסקה ביום המנוחה',
#        'פרטים אודות משאית MAN מדגם TGS',
#        'ניפוח שעות עבודה לצורך failure to respond', 'ציוני בגרות',
#        'תמיכות משרד ההתיישבות בהקמה ותפעול של מחלקות סיור ',
#        "מס' פניה 651507", 'צי האוטובוסים של חברת גלים',
#        'שריפות פסולת ואכיפה סביבתית', 'ביצוע החלטות הממשלה',
#        'העתק הסכם משרד הבריאות',
#        'failure to respond לפנייה דרך חוק חופש המידע',
#        'failure to respond', 'פרסום מזון וצער בעלי חיים',
#        'כמות ניפוקי קנאביס רפואי בפועל', 'בקשת מידע',
#        'התכתבויות בין משרד הבריאות לביח העמק בעניין מרשיי"',
#        'דוח בדיקה על השפעת נוכחות שיטור', 'מסמכים שונים -יועמש"',
#        'כלבי שירות בצהל"', 'צו 348: הנחיות מנהליות ומידע',
#        'הכנסת כספים לרצועת עזה', 'ביצוע בפועל של קווים שונים 2022-2023',
#        'קבלת דוח מומחה חיצוני"', 'מידע על צהרונים ופרטי קשר',
#        'נוהל המלצות להעסקת עובדים פלסטינים',
#        'פיקוח השירות הוטרינרי על אוניות המשמשות להובלת מקנה',
#        'מידע בדבר פעילות לאכיפת נוהל השתתפות סטודנטים ',
#        'פרישה ושחרור מצהל נוכח נסיבות רפואיות"', 'נהלי משרד התיירות',
#        'פטור חלקי ממס רכישה לנכה', 'פורמולת מזון לתינוקות נוטרילון',
#        'היתרי מופעים עם בעלי חיים', 'תקופת ההסתגלות השנייה',
#        'בקשה לקבלת מידע מכח חוק חופש המידע',
#        'הרכב הוועדה בנושא המדיניות על הסיגריות האלקטרוניות',
#        'שליחת מסמכים', 'בתי ספר מצטיינים',
#        'בקשה לקבלת מידע לפי חוק חופש המידע',
#        'failure to respond סמוכין 388601  10.09.23', 'אישור מסירת עיצום',
#        'מידע מפרקליטות המדינה פלילי', 'חלופות ניסויים בבעלי חיים',
#        'חוק יום הזיכרון ליצחק רבין במערכת החינוך',
#        'תלונה על failure to respond לבקשה לקבלת מידע על פי החוק',
#        'מידע בנושאים שונים בנושא קורונה', 'תוצאות הטיפול בחברת סנקי',
#        'קוד מוסד לישיבות', 'רכישת זכויות בגין שנים קודמות בשירות קבע',
#        'מתן נימוקים אודות החמרה בקריטריונים לחידוש רישיון',
#        'מענה מהמנכל"', 'הנחיות מנהליות וחקיקה ראשית ומשנית בצו 348',
#        "גב' דלית שטאובר - ניגוד עניינים וחוות דעת", 'הפגנות ומחאות',
#        'אישור ונימוקים להעלאת ארנונה - שערי תקווה',
#        'פרוטוקולים של הועדה הציבורית להרחבת סל השירותים',
#        'מידע בנושא הרפורמה בחינוך המיוחד', 'פרטי שכר ראש מטה מגן ישראל',
#        'אי קבלת מענה מפניות הציבור', 'בעלי חיים במוסדות חינוך',
#        'חוד היועמ"ש שהוגשה בעע"מ 6542/15"', 'אישור חיילים לשימוש בזרעם',
#        'מידע דחוף', 'בקשה לקבלת מידע לפי חוק חופש המידע התשנח - 1998"',
#        'מינויי השר לפקידי רישוי לכלי יריה', 'צוות איפכא מסתברא',
#        'מסמכים מהחלטת פקיד היערות להשגה',
#        'מחלת הסרטן במושב מאור (מחוז חיפה)', 'קבלת מידע (קיים)',
#        'ביקורת שעות בחטיבות עליונות', 'בוגרי החינוך החרדי בצהל"',
#        'פרוטוקולים', 'דוחות בקרה בגני תקשורת במודיעין', 'מסמכים אישיים',
#        'תשלום וטיפול בבקשות פורשים לקבלת העתק מן התיק האיש', 'תקצוב',
#        'מסמך מפורט מי היו חברי וועדת הערר',
#        'מאגר שות של מבחני טוענים רבניים"', 'אכיפה נגד מחאות',
#        'פרסום נהלים מינהל הבטיחות והבריאות',
#        'מידע לשנתון סטטיסטי- סיוע משפטי',
#        'קבלת מידע על מכונים לצילום רנטגן דנטליים', 'ועדת החמישה',
#        'קבלת רשימת תלונות שהוגשו', 'נבחרת הדירקטורים 2022',
#        'failure to respond סמוכין 394563 מתאריך 05.11.23 ',
#        'failure to respond אורן לביא מנכל לבקשת מידע 375457 "',
#        "פעילות אוטובוס מס' רישוי 37-789-55",
#        'נטילת זרע מנפטר - כריתת אשכים', 'קיצור שבוע הלימודים',
#        'נהלים ומדיניות- פרקליטות המדינה', 'גיור בישראל',
#        'גילוי מסמכים בעניין הצמדת מדד תשומות הבניה',
#        'דוח ביקורת מלון פלזה - נוף הגליל', 'אי-מתן מענה (מסד)"',
#        'מענה לחופש המידע', 'ועדת איתור ליועמש', 'אין מתן מענה',
#        'תאורה באסדת הגז לוויתן', 'תלונה על קבלת מידע שלא על פי החוק',
#        'תיק אישי של התמיד ', 'חיסון נשים הרות נגד נגיף הקורונה',
#        'תיק אישי', 'חיסון הפפילומה - יעילות ותופעות',
#        'קבלת סיכום טיפול בפניה', 'דוח תיקופים מפורט"',
#        'פחים כתומים עיריית ירושלים', 'הספריה הלאומית',
#        'הפגנה מיום 14/01/2023', 'בקשת מידע צווים שיפוטים',
#        'ניצול תקציבים', 'בירור בפרויקט מחיר למשתכן',
#        'תוכנית התחבורה הציבורית מואז שדות דן', 'פרטי מפעילי קייטנות',
#        'נתונים על שריפות פסולת ועל אכיפה סביבתית ביוש"',
#        'הסברה בציבור החרדי', 'בניין ארמון הנציב',
#        'בקשה לקבלת מידע ומסמכים בעניינה של המיוצגת ',
#        'השעיית תלמידי חינוך מיוחד בביס האלה במודיעין"',
#        'נתונים אודות פיטורים בעילת צמצום כוחות סדירים',
#        'ועדת איתור ליועמש"',
#        'ישיבות שר האוצר עם הגורמים המקצועיים במשרדו',
#        'העסקת פלסטינים במנהל הcitizenי',
#        'failure to respond לבקשת מידע סמוכין 378452   04.07.23   ',
#        'היתרים להעסקת עובדים זרים', 'מידע אישי', 'פרטים אודות מכון הדרום',
#        'זיהומים ומכונות אקמו', 'תגובות לתלונות', 'יחידת צור',
#        'פנייתי לחוק חופש המידע במשרד הבריאות 283829',
#        'בקשות - וועד מקומי פדואל', 'נתונים אודות חיילים בודדים בצהל"',
#        'קבלת תיק אישי', 'פעילות משרד האוצר ביחס לפנסיה הצוברת בצהל"',
#        'קבלת הצו על הצבת שלט שטח צבאי סגור" בשטח פרטי"', 'הקצאת מקרקעין',
#        'בקשה לקבלת מידע אודות אישורי כבאות במחוז צפון',
#        'נשים מאוימות בלוד', 'דיג מכמורת לצרכי מחקר מצפון לדור',
#        'מניעת נישואי קרובים- בנק הזרע', 'כתבי אישום בעבירות הסתה  לפי דת',
#        'failure to respond  סמוכין 392585 מתאריך 13.10.23 ',
#        'קבלת הוראת נוהל', 'צטמ וצוות להתפרצות הפוליו - ניגודי עניינים"',
#        'נהלי חקירת ירי', 'מימון לתהליכי שינוי מין', 'אסירים זרים',
#        'וועדת ההיגוי לטיפול במרחבים סגורים ',
#        'יישום החלטת ממשלה 1226 - הוקרה, סיוע ותגמול לחיילי מילואים המשרתים במלחמת חרבות ברזל" ותיקון החלטת ממשלה"',
#        'מפעלי מזון במחוז חיפה', 'עגורנאים',
#        'מסמכים ביחס לדיווח על אשפוזו ומותו של איתי למברסקי',
#        'מתן כמויות  של מים שהוזרמו לאגודה ובקשות נוספות',
#        'אלין בית נועם - פרוטוקולים', 'פיילוט הסעות בחינוך המיוחד',
#        'דין משמעתי של חיילי צהל"', 'שאלוני שביעות רצון חדר 4',
#        'ניגודי עניינים בועדת סל התרופות',
#        'אכיפה ורגולציה בענפי החקלאות מהחי',
#        'מסדרון וצוואר בקבוק אקולוגי גדרה', 'חלופות ניסויים משרד הבריאות',
#        ' דיווחים על תופעות לוואי בדף הפייס', 'דוחות נתוני איכות אויר',
#        'עיון בהקדש', 'הכנסת והוצאת כספים אל ומרצועת עזה', 'חופש מידע ',
#        'התקשרויות מערכת הביטחון הוראת שעה', 'קיצור ימי לימודים תשפג',
#        'נתונים על בקשות לקבלת רשיון נשק',
#        'אישור או התנגדות למינוי מנהלי עבודה בבנייה',
#        'מסמכים בגין בקשה להיתר בניה', 'נתונים תגמולים אלמנות צהל"',
#        'אי-מתן מענה', 'הגרלה 472 פרוייקט השמורה" - האחים חסיד"',
#        'נוהל פריסת פקחים בקווי עליה מכל הדלתות', 'פרוטוקול ועדת האכיפה',
#        'פנייה מספר 285393', 'פרוייקט צילה"', 'גיורים וועדות חריגים',
#        'בקשה לקבלת סיכום פגישה קמין עצים',
#        'אימות מידע שהתקבל ממוסד other ',
#        'מידע על זכאות משפחות לתווי מזון לפי ישוב ',
#        'תעודות מעבר לילדי אומנה חסרי מעמד ',
#        'זמני המתנה לניתוח להתאמה מגדרית',
#        'קבלת חומרים נלווים בנוגע לפרסום', 'מיזם אמפיסטאר מכתש רמון',
#        'מדיניות התנדבות ', 'פעילות מוקד הסביבה',
#        'בירור לגבי העברת מענק מיוחד', 'מחלת פוליו בארץ',
#        'מידע חייב בפרסום לעניין אישי', 'פעילות הדסק החרדי בקורונה',
#        ' פרטים על הוועדה המייעצת בנושא מינוי דירקטורים',
#        'מידע לגבי יבוא טובין', 'נתונים לגבי תווי המזון - סבב שני ',
#        'מידע בנוגע להרחבה בכפר פינס, תוכניות והסכם פשרה', 'אגף הדיג',
#        'החלטות בדבר בנק הדם', 'failure to respond גם otherי ארכה',
#        'מידע על התנהלות בשער שני במודל הקבע',
#        'מספר הפלסטינים בגדה המערבית וברצועת עזה', 'מתווכים',
#        'מידע על אגף שיקום נכים במשהבט',
#        'פגישות נציגי צהל עם נציגי משרד האוצר בנושא תקנות "',
#        'הוספת סטודנטים לרפואה',
#        'failure to respond סמוכין 361890 מתאריך 01.03.23 ',
#        "נהלי טראנסג'נדרים ", 'הסדר ניגוד עניינים', 'קביעת תאריך גיוס',
#        'failure to respond סמוכין 395069 תאריך 09.11.23 ',
#        'failure to respond בבקשה לקבלת מידע על פי חוק',
#        'failure to respond לבקשה 11.08.23 סמוכין  384552 ',
#        'קבלת עותק רישיון רטן"', 'בקשת מידע - עבודת מטה',
#        'פירוט התקשרויות מאושרות למחקר', 'נתוני משפטנים בצהל"',
#        'בקשה לקבלת מידע בעניין רשימת המדינות כאמור בבקשתנו',
#        'בירור אפלייה ותנאי רפורמת אופק חדש',
#        'סגירת שלוחת ביהח שערי צדק ברח\' הנביאים"',
#        'מסמכים לגבי החיסון מותאם אומיקרון', 'דוח תאונת עבודה',
#        'אמיר לנציאנו', 'שימועים בגין עבירות בטיחות – רשם הקבלנים',
#        'העלמת מידע ', 'מבחן מחוננים', 'לימודי תרפיה באומנויות',
#        'קבלת העתק מסמך תשובת שר האוצר', 'פסקי דין מאושרים לצו 348',
#        'צו הורות פסיקתי', 'פעילות המשטרה הירוקה',
#        'כספים שהוקפאו מהרשות הפלסטינית', 'אצוות חיסון פייזר',
#        'פעולות אכיפה בתחום איכות הסביבה',
#        'הוצאות משרד הבריאות על משפיעני רשת',
#        'עלות חכירת מטוס מסחרי לטיסות', 'אופן חישוב השתתפות בדמי אשפוז',
#        'רותם אמפרט', 'פרטים על מורי החטיבות העליונות',
#        'כריתת אשך ללא הסכמה',
#        'מתן חסויות על ידי משרד הכלכלה ועובדי ציברר ממשרד ה',
#        'הנילונה לא מסרה את המסמכים המבוקשים', 'חופש מידע',
#        'שריפות גזם ופסולת חקלאית', 'דוחות תנועה בצומת "',
#        'מעקב תהליכים - שאלון', 'בקשה למידע ציבורי- הקצאות מקרקעין',
#        'נתונים על אירועים לבבים בצהל בשנים 18-21"',
#        'מידע בנושא מעבר מבחני רשיונות', 'מידע בנוגע לפעילות יחידת הפיקוח',
#        'נתונים אודות תחומים שונים (ריטלין, פסיכיאטריה, נזעי חשמל, פירכוס, אובדנות, אשפוז בכפיה ועוד)',
#        'אופן הטלת מניעה', 'מספר עובדים עם מוגבלות משמעותית ',
#        'קבלת מידע על מכללות לתחבורה בצפון', 'אי קבלת מענה ענייני',
#        'תגמולים לחברות על תיקופים של הנוסעים', 'פירוט חלוקת תמיכות',
#        'פרוטוקול וועדה פריטטית', 'בקשה לקבלת תיק חקירה פלא 19/373477"',
#        'בקשות ותכניות', 'מספר מקוצר כוכבית וארבע ספרות',
#        'המסלקה הפנסיונית', 'מידע על עסקאות ',
#        'failure to respond !במועד! סמוכין 394794 תאריך 07.11.23 ',
#        'כתבי אישום', 'תיקון העלון לתרופת פרופסיה',
#        'וועדת החריגים תמריצים',
#        'failure to respond לבקשת מידע  29.01.23 סמוכין 357354 ',
#        'נגישות לאנשים עם מוגבלות', 'מחקר תחלואת סרטן עודפת',
#        'פרוטוקולים ותכוניות בנייה', 'הכשרות שופטים בנושא אלימות מינית',
#        'קבלת מידע נוקדות חובה',
#        'failure to respond לבקשה סמוכין 378524 04.07.23 ', 'שמאי מכריע',
#        'מדיע בנוגע להפעלת סמכות מקבילה',
#        'פניה מתאריך ה- 27.06.2022 - failure to respond',
#        'תמהיל דירות פרויקט 1572 בתוכנית מחיר למשתכן ',
#        'אי מתן מתן לקבלת תקנות ', 'חוק הפחמן',
#        'פנייה לנציב קבילות הרופאים', 'נתונים על דין משמעתי',
#        'אשפוז עקב חשיפה לחום', 'ניסויים בבעלי חיים במשרד הביטחון',
#        'החלטות וועדות, מידע אודות המבקש ומידע סטטיסטי',
#        'failure to respond לבקשה 07.05.23 סמוכין 370052 ', 'אמל שבלי',
#        'חלוקת מכסות בענף התעשייה והשירותים',
#        'שינוי סיווג מערכי נגדים במהלך חופשת הפסח 2023',
#        'failure to respond על נתונים שנתבקשו בבקשת חופש מידע ',
#        'בקשה למידע במסגרת חוק חופש המידע', 'תרומות למחקרים קליניים',
#        'מידע על תקציבים ועל ארגוני המורים',
#        'תלונה נגד רכזת האגף במשרד החינוך אילנית שושני',
#        'חוזה מול מועדון הלקוחות יותר""',
#        'בקשה לקבלת מידע בעניין דר אשר שלמון"',
#        'ועדת האיתור לתפקיד מנהל לפמ"', 'כרם שיזף',
#        'צווים שהוטלו על ידי המפחק סימיון',
#        'הקלטת שיחה אשר ביצעתי עם המשרד', 'קביעת שכר דירה',
#        'דוח תיקופים קו 681', 'מסמכי יכולת פיננסית',
#        'היתרי כניסה לישראל לצורכי עבודה ומניעות כניסת תושב',
#        'שימוש בפיקדון צבאי',
#        'מידע על הריסות בתים, פינויים וחריש בנגב לשנת 2021',
#        'עיון בתיק אישי - בית הספר שלנו תל מונד',
#        'מענים חלקיים בלבד לשתי בקשות מידע', 'פילוח תלונות מחש"',
#        'השלכות מס הסוכר', 'סמכות ועדה פריטטית בנושא התמריצים למורים ',
#        'חכירת רכבים מצהל"', 'מתן מענה לא ענייני וחלקי ביותר', 'קבלת מידע',
#        'מפעלי תעשייה כבידה בישראל',
#        'החזר כספים בגין הפקדות כספי מעסיק מקופות שונות',
#        'תכנית כיבוי אש פרויקט דניה סיבוס',
#        'failure to respond סמוכין 373500 תאריך 31.05.23 ',
#        'פרסום כתבות נגד משרתי ופורשי צבא הקבע',
#        'failure to respond לבקשת מידע ',
#        'failure to respond לבקשת חופש מידע מיום 11.12.22 ',
#        'מידע על כמויות מים והיכן נצרכו', 'מסמכים  שונים',
#        'בקשה הנוגעת לחווד אודות פטריק דרהי',
#        'אי כיבוד הבקשה, גרירת רגליים ופעולה ללא סמכות',
#        'מכות חום, חשיפה לקרינה וכמות בשר', 'צווי הרחקה מנהליים',
#        'אי התייחסות לבקשה.',
#        'חופש המידע בתי דין רבניים מקומות מושב דיינים',
#        'מסמך הנחיות של יועץ הבטיחות מטעם משרד החינוך',
#        'מוניטור 1226 ו-3741', 'אכיפה וקנסות - אי דיווח תרומות',
#        'פילוח נתוני מחש"', 'כתבי מינוי נוספים של עוד בנימין זלמנוביץ"',
#        'failure to respond בקשת 14.04.23 סמוכין 366866 ',
#        'נתונים אודות בקשות חופש מידע המוגשות לצהל"',
#        'דוחות הדרכות בטיחות', 'חופש מידע מפרקליטות מחוז תא ומרכז "',
#        'ביקשתי נוהל וקיבלתי תשובה מתחמקת אך לא הנוהל',
#        "מינויה של פרופ' שורץ לבחון חומר בנושא פרשת ילדי תימן",
#        'נוהל קריטריונים הקמת ועדת בדיקה רשמית, רשלנות רפואית',
#        'מידע לשנתון סטטיסטי', 'מדיניות גיוס בני ישיבות ציונית',
#        'אנטיביוטיקה מסוג CEFTRIAXONE', 'תלונות למחש"',
#        'רישיונות או היתרים לדיג חריג', 'דוח חקירת אירוע שריפה',
#        'תקנות זכויות התלמיד', 'נתונים לגבי מחסור בעובדי הוראה',
#        'הועדה לשינוי מין', 'בקשת חופש מידע', 'מכונות אקמו',
#        'רשימת בתי מלון',
#        'failure to respond ! במועד ! סמוכין 396840 תאריך 24.11.23',
#        'יועצים חיצוניים ועובדי המדינה לרוהמ שהושכרו ע"י המשרד בחודשים אוקטובר 2023 עד מאי 2024"',
#        'נתונים מהוצאה לפועל והמרכז לגביית קנסות',
#        'דוח ביקורת כספית בישיבה תיכונית גבעת שמואל"',
#        'בקשת חוק חופש המידע', 'נתונים על משרתות מילואים',
#        'אישור ו/או קבלת רישיון מוסד מכורים לחיים""',
#        'failure to respond ! במועד ! סמוכין 397777 03.12.23 ',
#        'פרוטוקולים לשכת היועמש', 'אי מענה לקבלת תקנות ',
#        'נורות פוטותרפיה',
#        'בקשה לדוח כיבוי חוקר דליקות על שריפה בין 15-14 יולי 2023 בבניין ברחוב יוסף הגידם 13 חיפה"',
#        'failure to respond לבקשת מידע סמוכין 397772 03.12.23 ',
#        'מערך הפיקוח על המזון ', 'ביקורות בחזיריות',
#        'שיתוף פעולה בין מנהל הבטיחות בזרוע ויחידת פלס',
#        'פרוטוקולים שונים', 'מספר בוגרים ישראלים מחול"',
#        'השלמת נתונים - יוצאי אתיופיה',
#        'תקצוב משרד התחבורה פרויקטים תחבורתיים וסובסידיות בגדה המערבית',
#        'שאלות לגבי בידוד נגיף הקורונה',
#        'בקשה לקבלת אסמכתאות להעברת כספים', 'הפעלת סמכותו של מנהל המחוז',
#        'הליכי גיוס לבעלי קושי נפשי', 'העתק ממסמכי מכרז',
#        'קבלת מידע בנושא תאי לחץ גבוה ומתון', 'העתק ממרשם האוכלוסין',
#        'כיסוי חיסוני בישראל ומדיניות הסברה',
#        'משלוח מזון מבית עסק לבית הצרכן', 'התפרצויות חצבת בעולם',
#        'failure to respond לבקשתי לרשומות מהפסיכיאטר המחוזי מרכז',
#        'החלטת ממשלה 682', 'הטלת קנסות על החברות המשכנות ותלונות הציבור',
#        'נתוני אסירים בטחוניים 2021',
#        'תשלום למודיע על השלכת פסלת שלא כדין', 'פרוטוקול תחבורה ציבורית ',
#        'מידע אודות הוסטל נחלים ברכסים', 'בני מהגרים בלימודים',
#        'תנאי הזכאות לקבלת גמול השתלמות (גמוש) לקצינים בשירות קבע"',
#        'בקשה לקבלת סקרי קרקע בתחנת דלק', 'קבלת מידע מה עלה ',
#        'כתבי אישום בחתך דת', 'החלטות ונהלים בנושא שינוי בשבן"',
#        'תנאי עבודה', "חיוב אגרת שמירה בניגוד לתקנון וגם ביח' משנה",
#        'כתובת המוסד בית התלמוד שערי תורה', 'נהלי פטורים טוענים רבניים',
#        'נהלים ומדיניות- פמי"', 'בקשת מידע אישי',
#        'פילוח הפיקוד הבכיר בצהל לפי חינוך"',
#        'עובד ודיינים שהושהו בסוף 2016',
#        'ענישה במקרי עבירות בטחון בבימש הצבאיים באיו"ש"',
#        'אישור היועמש למתן אישורים בדיעבד"', 'לידות שקטות והפלות',
#        'תחבורה ציבורית', 'אי קבלת מענה רשמי ', 'מכשיר INVOS',
#        'שומת מקרקעין בגוש 7079 חלקה 12',
#        'failure to respond !במועד! סמוכין 383730 תאריך 06.08.23 ',
#        'חקירות אישי ציבור', 'צווי בטיחות חברת ארקאן',
#        'מדידות כיסוי סלולרי בכביש 31',
#        'מיפוי מספר מסגרות ייעודיות ותלמידים עם אוטיזם',
#        'דיווח תרומות למשרד הבריאות', "חיות משק במלחמת 'חרבות ברזל'",
#        'פעילות משרד האוצר בתקשורת ביחס לשכר, תנאים',
#        'שכר רבנים שכר ממונה חשיפה', 'פנייה 99072',
#        'מתן חסות עובד ציבור על ידי מנכל משרד הכלכלה "',
#        'ארגונים מאושרים על ידי שר המשפטים',
#        'מסמכי הפרויקט הידוע כמנהטן 15 " בנתיבות"',
#        "מידע-מס' בקשות שלא נענו בצורה תקינה", 'אסירי עולם',
#        'רשיונות ללא מגע""', 'תרופות מתחדשות',
#        'מתן מידע לפי חוק חופש המידע', 'העברת מסמכים ',
#        'ערעור טובין בייבוא אישי', 'יישום חוק חובת דיווח', 'אי קבלת מענה',
#        'פיגומים ממוכנים', 'תיעוד מגן אסיף',
#        'failure to respond ממשרד התחבורה',
#        'אי קבלת מענה ומענה משתלח מצד הגורם ברשות', 'מיחזור צמיגים',
#        'מידע סטטיסטי לשנתון', 'עדכון מניעויות רשמים',
#        'לוחות המזון לעצורים ולאסירים ביטחוניים',
#        'תחומי otherיות כפר יונה', 'מעברים לרצועת עזה',
#        'תיקי פלא נוער בהפגנות"',
#        'failure to respond !במועד! סמוכין 395054 תאריך 08.11.23 ',
#        'תיקון שירטוט קו 50 במושב רום אל און ', 'מסמכי חידוש רישיון',
#        'אי קבלת מענה חופש המידע', 'פנייתי 65539',
#        'רשימת משווקי בשר, עופות ודגים ומספרי הזיהוי הווטרינרי שלהם',
#        'פרוטוקול רכבת', 'השמדת קנאביס רפואי',
#        'בקשה לקבלת מידע עבור בית ספר בחיפה', 'הנחיית משרד המשפטים',
#        'פירוט הטיפול בטופס פניות הציבור', 'יבוא ושיווק דגים ומוצרי דגים',
#        'בקשה לדוח כיבוי דליקה בין 15-14 יולי 2023 בבניין ברחוב יוסף הגידם 13 חיפה"',
#        'ישיבות הסדר', 'מסירת מידע לא מדויק/שקרי', 'נוהל יממ',
#        'פסילת הרכב דיינים בנתניה 2020 - 2022', 'מועדון הזמר האילתי',
#        'שירותים והתקשרויות בין משרד הבריאות למדא לשנים 2019-2020"',
#        'טיפול בבקשות לרישיונות לשאת כלי ירייה פרטי',
#        'קרן תובענות יצוגיות ', 'מסמכים הנוגעים לחברת גלים',
#        'דיג במפרץ אילת',
#        'failure to respond סמוכין 392394 מתאריך 11.10.23 ',
#        'זמני המתנה לרופאים בקהילה', 'תוכנית 2023 של פקידי יערות',
#        'failure to respond והודעת ארכה לא לפי חוק',
#        'סירוב גורף לבקשת מידע  מיום 16.4.23',
#        'תחלופת עובדים בלשכות הנהלה', 'הסכמי התקשוריות ומכרזים',
#        'בידוד נגיף הקורונה'], dtype=object)

# %% [markdown]
# Unfortunately it seems like this data is pretty unique. There aren't a lot of recurring topics, but the top ones (below) are: <br>
# ```
# Urgent information             7
# Data about psychiatric wards   7
# Request for information        4
# Support distribution details   4
# Failure to respond             3
# ```

# %%
df["original_request_topic"].value_counts()[:30]
# Out:
# original_request_topic
# מידע דחוף                                                   7
# נתונים על מחלקות פסיכיאטריות                                7
# בקשת מידע                                                   4
# פירוט חלוקת תמיכות                                          4
# failure to respond                                          3
# בקשות ותכניות                                               2
# תקציבי פרסום                                                2
# חאן לבונה                                                   2
# הקצאת מקרקעין                                               2
# הוספת סטודנטים לרפואה                                       2
# יישום חוק חובת דיווח                                        2
# שריפות פסולת                                                2
# תחומי otherיות כפר יונה                                     2
# תאורה באסדת הגז לוויתן                                      2
# נהלי משרד התיירות                                           2
# מידע בנושאים שונים בנושא קורונה                             2
# תקצוב משרד התחבורה פרויקטים תחבורתיים וסובסידיות ב          2
# failure to respond !במועד! סמוכין 395054 תאריך 08.11.23     2
# בקשה לקבלת מידע לפי חוק חופש המידע                          2
# הכנסת והוצאת כספים אל ומרצועת עזה                           2
# הנחיות בגיור                                                2
# failure to respond סמוכין 394563 מתאריך 05.11.23            2
# מתן מענה לא ענייני וחלקי ביותר                              2
# עיון בתיק חקירה 16020                                       2
# חלופות ניסויים משרד הבריאות                                 2
# הכשרות שופטים בנושא אלימות מינית                            1
# פרוטוקולים ותכוניות בנייה                                   1
# מחקר תחלואת סרטן עודפת                                      1
# failure to respond !במועד! סמוכין 394794 תאריך 07.11.23     1
# נגישות לאנשים עם מוגבלות                                    1
# Name: count, dtype: int64

# %% [markdown]
# ### let's look at the complaints whose handling is not complete
# There are only 15, which is not much to work with. <br>
# They all seem to be pretty "fresh" (longest one has been around for 30 days) <br>
# 8 out of 15 complaints were filed against the Ministry of Health.

# %%
undergoing = df[df["status"] == "undergoing treatment"]
undergoing
# Out:
#     request_date complaint_date complaint_channel          complainer_kind  \
# 183   13/06/2024     08/11/2024       online form  non-profit organization
# 225   19/05/2024     25/11/2024       online form                    other
# 249   18/04/2023     10/11/2024       online form                  citizen
# 251   18/06/2024     01/11/2024       online form                  citizen
# 257   14/07/2024     20/11/2024       online form                  citizen
# 261   20/07/2023     26/11/2024       online form                  citizen
# 286   22/08/2023     10/11/2024       online form                  citizen
# 350   06/05/2023     07/11/2024       online form                  citizen
# 359   15/07/2024     20/11/2024       online form                    other
# 403   18/09/2024     03/11/2024       online form                  citizen
# 416   08/08/2024     10/11/2024       online form                  citizen
# 476   04/10/2024     11/11/2024       online form                  citizen
# 490   10/09/2024     26/11/2024       online form  non-profit organization
# 632   05/07/2023     09/11/2024       online form                  citizen
# 653   29/08/2024     29/10/2024       online form                  citizen
#
#                           complainer_name     complaint_topic  \
# 183  נדן - סיוע משפטי לחיילים בשירות חובה  failure to respond
# 225                                   NaN  failure to respond
# 249                                   NaN  failure to respond
# 251                                   NaN  failure to respond
# 257                                   NaN  failure to respond
# 261                                   NaN  failure to respond
# 286                                   NaN  failure to respond
# 350                                   NaN  failure to respond
# 359                                   NaN  failure to respond
# 403                                   NaN  failure to respond
# 416                                   NaN  failure to respond
# 476                                   NaN   lack of reasoning
# 490         תחרות - התנועה לחירות בתעסוקה  failure to respond
# 632                                   NaN  failure to respond
# 653                                   NaN  failure to respond
#
#                     complaint_against                original_request_topic  \
# 183                              צהל"           תמיכות, עבירות ומשמעת, ועוד
# 225                      משרד המשפטים           מידע מפרקליטות המדינה פלילי
# 249                      משרד הבריאות                     צוות איפכא מסתברא
# 251                      משרד הבריאות     מחלת הסרטן במושב מאור (מחוז חיפה)
# 257                      משרד הבריאות       דוחות בקרה בגני תקשורת במודיעין
# 261                      משרד הבריאות     מסמך מפורט מי היו חברי וועדת הערר
# 286                      משרד הבריאות      חיסון נשים הרות נגד נגיף הקורונה
# 350                      משרד הבריאות     דיווחים על תופעות לוואי בדף הפייס
# 359  מנהל citizenי אזור יהודה ושומרון           מסמכים בגין בקשה להיתר בניה
# 403                        משרד הפנים                 בקשת מידע - עבודת מטה
# 416                      משרד הבריאות                לימודי תרפיה באומנויות
# 476                המשרד להגנת הסביבה                             חוק הפחמן
# 490                       משרד החינוך     מידע על תקציבים ועל ארגוני המורים
# 632                      משרד הבריאות                        תרופות מתחדשות
# 653      משרד התחבורה והבטיחות בדרכים  תיקון שירטוט קו 50 במושב רום אל און
#
#                    status decision termination_date  days_to_treat
# 183  undergoing treatment      NaN              NaN             20
# 225  undergoing treatment      NaN              NaN              3
# 249  undergoing treatment      NaN              NaN             18
# 251  undergoing treatment      NaN              NaN             27
# 257  undergoing treatment      NaN              NaN              8
# 261  undergoing treatment      NaN              NaN              2
# 286  undergoing treatment      NaN              NaN             18
# 350  undergoing treatment      NaN              NaN             21
# 359  undergoing treatment      NaN              NaN              8
# 403  undergoing treatment      NaN              NaN             25
# 416  undergoing treatment      NaN              NaN             18
# 476  undergoing treatment      NaN              NaN             17
# 490  undergoing treatment      NaN              NaN              2
# 632  undergoing treatment      NaN              NaN             19
# 653  undergoing treatment      NaN              NaN             30

# %% [markdown]
# ## dates!

# %%
from ipywidgets import interact, IntSlider, FloatSlider, Text, SelectionSlider, RadioButtons, Dropdown, DatePicker

# %%
#some rows have "termination_date" as NaN (like complaints that are not terminated), so we must drop them first
df_termination_clean= df.dropna(subset=["termination_date"])

# %%
#What is the type of the date?
type(df["termination_date"].iloc[0])
# Out:
# str

# %%
#So we must convert that to a usable timestamp format
df_termination_clean["termination_date"] = pd.to_datetime(df_termination_clean["termination_date"].str.strip(), format="%d/%m/%Y")
# Out:
# /var/folders/b5/0ytjq561357277rwx5t5p9r40000gn/T/ipykernel_5911/4133803517.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_termination_clean["termination_date"] = pd.to_datetime(df_termination_clean["termination_date"].str.strip(), format="%d/%m/%Y")

# %%
type(df_termination_clean["termination_date"].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
monthly_complaints = df_termination_clean.groupby('year_month').size().reset_index(name='complaint_count')

# %%
monthly_complaints
# Out:
#    year_month  complaint_count
# 0     2021-05                4
# 1     2021-06                6
# 2     2021-07                4
# 3     2021-08               19
# 4     2021-10                2
# 5     2021-11               19
# 6     2021-12                8
# 7     2022-01                1
# 8     2022-02               26
# 9     2022-03               45
# 10    2022-04               19
# 11    2022-05               39
# 12    2022-06               11
# 13    2022-07               16
# 14    2022-08               28
# 15    2022-09               16
# 16    2022-12               10
# 17    2023-01                8
# 18    2023-02               11
# 19    2023-03               14
# 20    2023-04                8
# 21    2023-05               35
# 22    2023-06               18
# 23    2023-07               25
# 24    2023-08               17
# 25    2023-09               20
# 26    2023-11                5
# 27    2023-12               21
# 28    2024-01               24
# 29    2024-02               18
# 30    2024-03               22
# 31    2024-04               19
# 32    2024-05               18
# 33    2024-06               15
# 34    2024-07               25
# 35    2024-08               27
# 36    2024-09               17
# 37    2024-10               21
# 38    2024-11               12

# %%
def complaints_by_year(year):
    filtered_data = monthly_complaints[monthly_complaints["year_month"].dt.year == year]
    monthly_counts = filtered_data.groupby(filtered_data["year_month"].dt.month)["complaint_count"].sum().reset_index()

    plt.figure(figsize=(10, 6))
    plt.bar(monthly_counts["year_month"].astype(str), monthly_counts["complaint_count"], color="powderblue")
    plt.xlabel("Month")
    plt.ylabel("Number of Complaints")
    plt.title(f"Complaints terminated in {year}")
    plt.xticks(rotation=90)

    #I want to set a limit to the Y axis so they all remain relative to each other
    plt.ylim(0, monthly_complaints["complaint_count"].max())

    #I also want to show the total amount of complaints for easier understanding
    plt.text(0.95, 0.95, f"Total Complaints: {monthly_counts["complaint_count"].sum()}", transform=plt.gca().transAxes, 
             ha='right', va='top', fontsize=12, bbox=dict(facecolor='white', edgecolor='none', alpha=0.5))
    
    plt.show()

interact(complaints_by_year, 
         year=Dropdown(options=sorted(monthly_complaints['year_month'].dt.year.unique()), 
                       value=monthly_complaints['year_month'].dt.year.max(),
                       description="Select Year"))
# Out:
# interactive(children=(Dropdown(description='Select Year', index=3, options=(2021, 2022, 2023, 2024), value=202…
# <function __main__.complaints_by_year(year)>

# %% [markdown]
# **What can we learn from this?** <br>
# Can't really address 2021 because the database only includes data from the end of April.
# The complaint amount per year after that is similar.
# The complaints are distributed pretty evenly in 2024, but not as much in 2023 and even less so in 2022.
# These are complaints that were terminated, not filed on those dates.

# %% [markdown]
# ### Let's see how many days are there between the original requests for information and the complaint date

# %%
df["request_date"] = pd.to_datetime(df["request_date"], errors="coerce")
df["complaint_date"] = pd.to_datetime(df["complaint_date"], errors="coerce")

df['days_to_complain'] = (df['complaint_date'] - df['request_date']).dt.days

df_clean = df.dropna(subset=['days_to_complain'])

df_clean
# Out:
#     request_date complaint_date complaint_channel          complainer_kind  \
# 0     2023-11-22     2024-10-28       online form                  citizen
# 1     2020-11-17     2021-05-01       online form                  citizen
# 2     2020-10-29     2021-05-01       online form                  citizen
# 3     2020-10-29     2021-05-01       online form                  citizen
# 4     2020-10-29     2021-05-01       online form                  citizen
# ..           ...            ...               ...                      ...
# 683   2023-11-08     2024-04-02       online form                  citizen
# 684   2024-08-25     2024-09-04       online form                  citizen
# 685   2024-01-11     2024-06-19       online form  non-profit organization
# 686   2022-08-16     2022-11-29       online form                  citizen
# 687   2022-06-14     2022-07-21       online form                  citizen
#
#     complainer_name     complaint_topic  \
# 0               NaN  failure to respond
# 1               NaN  failure to respond
# 2               NaN  failure to respond
# 3               NaN  failure to respond
# 4               NaN  failure to respond
# ..              ...                 ...
# 683             NaN  failure to respond
# 684             NaN   lack of reasoning
# 685           מוסרי  failure to respond
# 686             NaN  failure to respond
# 687             NaN  failure to respond
#
#                                     complaint_against  \
# 0                                 משרד הבינוי והשיכון
# 1                                     בית חולים רמבם"
# 2                         המרכז לבריאות הנפש שער מנשה
# 3    המרכז לבריאות הנפש באר-יעקב נס-ציונה מבן (שב"ס)"
# 4                            מרכז בריאות הנפש באר שבע
# ..                                                ...
# 683                                      משרד המשפטים
# 684                                 בית חולים איכילוב
# 685                               המשרד לשוויון חברתי
# 686                                      משרד הבריאות
# 687                      משרד התחבורה והבטיחות בדרכים
#
#                                 original_request_topic  \
# 0                   בירור פרטני לעניין קביעת שכר הדירה
# 1                        נתונים על מחלקות פסיכיאטריות
# 2                        נתונים על מחלקות פסיכיאטריות
# 3                        נתונים על מחלקות פסיכיאטריות
# 4                        נתונים על מחלקות פסיכיאטריות
# ..                                                 ...
# 683  failure to respond !במועד! סמוכין 395054 תאריך...
# 684                         תחלופת עובדים בלשכות הנהלה
# 685                            הסכמי התקשוריות ומכרזים
# 686                                 בידוד נגיף הקורונה
# 687                            תחומי otherיות כפר יונה
#
#                        status             decision  ... days_to_treat  \
# 0    termination of treatment          unjustified  ...             7
# 1    termination of treatment          unjustified  ...            22
# 2    termination of treatment            justified  ...           200
# 3    termination of treatment            justified  ...           200
# 4    termination of treatment            justified  ...           200
# ..                        ...                  ...  ...           ...
# 683  termination of treatment          unjustified  ...             1
# 684  termination of treatment          unjustified  ...             5
# 685  termination of treatment            justified  ...             8
# 686  termination of treatment            justified  ...            93
# 687  termination of treatment  justified partially  ...             5
#
#      year_month dates_match  termination_year_month complaint_year_month  \
# 0       2024-11       False                 2024-04              2024-10
# 1       2021-05       False                     NaT              2021-05
# 2       2021-11       False                     NaT              2021-05
# 3       2021-11       False                     NaT              2021-05
# 4       2021-11       False                     NaT              2021-05
# ..          ...         ...                     ...                  ...
# 683     2024-04       False                 2024-03              2024-04
# 684     2024-09       False                 2024-09              2024-09
# 685     2024-06       False                     NaT              2024-06
# 686     2023-03       False                 2023-02              2022-11
# 687     2022-07       False                     NaT              2022-07
#
#     request_year_month time_diff  complaint_date_num  request_date_num  \
# 0              2023-11      -341        1.730074e+09      1.700611e+09
# 1              2020-11      -165        1.619827e+09      1.605571e+09
# 2              2020-10      -184        1.619827e+09      1.603930e+09
# 3              2020-10      -184        1.619827e+09      1.603930e+09
# 4              2020-10      -184        1.619827e+09      1.603930e+09
# ..                 ...       ...                 ...               ...
# 683            2023-11      -146        1.712016e+09      1.699402e+09
# 684            2024-08       -10        1.725408e+09      1.724544e+09
# 685            2024-01      -160        1.718755e+09      1.704931e+09
# 686            2022-08      -105        1.669680e+09      1.660608e+09
# 687            2022-06       -37        1.658362e+09      1.655165e+09
#
#      days_to_complain
# 0                 341
# 1                 165
# 2                 184
# 3                 184
# 4                 184
# ..                ...
# 683               146
# 684                10
# 685               160
# 686               105
# 687                37
#
# [688 rows x 21 columns]

# %%
df_clean['days_to_complain'].plot(kind="hist", bins = 72, color = "seagreen",
                                  xlabel="days between request and complaint",
                                  ylabel="number of complaints",
                                  title="time between original request for information and filing a complaint",
                                  xticks=range(int(df_clean["days_to_complain"].min()), int(df_clean['days_to_complain'].max()), 100)
                                 )
# Out:
# <Axes: title={'center': 'time between original request for information and filing a complaint'}, xlabel='days between request and complaint', ylabel='number of complaints'>
